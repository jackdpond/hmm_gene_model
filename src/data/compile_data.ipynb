# %%
import pandas as pd
import GEOparse as gp

# %%
# download GEO dataset
gse = gp.get_GEO(geo="GSE3431", destdir="./")

# Compile samples
compiled_data = gse.pivot_samples("VALUE")

# Save as csv file
compiled_data.to_csv("geo_samples_data.csv")
# Out:
# 14-Mar-2026 09:28:05 DEBUG utils - Directory ./ already exists. Skipping.
# 14-Mar-2026 09:28:05 INFO GEOparse - File already exist: using local version.
# 14-Mar-2026 09:28:05 INFO GEOparse - Parsing ./GSE3431_family.soft.gz:
# 14-Mar-2026 09:28:05 DEBUG GEOparse - DATABASE: GeoMiame
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SERIES: GSE3431
# 14-Mar-2026 09:28:05 DEBUG GEOparse - PLATFORM: GPL90
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77298
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77299
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77300
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77301
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77302
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77303
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77304
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77305
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77306
# 14-Mar-2026 09:28:05 DEBUG GEOparse - SAMPLE: GSM77307
# ...
